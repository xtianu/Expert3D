# %% [markdown]
# <a href="https://colab.research.google.com/github/raulbenitez/EXPERT3D/blob/main/hello_world_image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import skimage as sk # load skimage libraries

IC = sk.data.astronaut() # load a color image from the skimage built-in dataset
sk.io.imshow(IC) # visualize image using imshow function
sk.io.show() 
print('M = {} columns, N = {} rows, NC = {} color channels'.format(*IC.shape)) # Print out image size and color channels
# Out:
# M = 512 columns, N = 512 rows, NC = 3 color channels
